# %% [markdown]
# # Demo
#
# This notebook demos the use of a Kalman filter to recover the states for the model described in [Vargas and Melatos 2023](https://arxiv.org/pdf/2305.09079.pdf)

# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import json 
import pandas as pd 
try:
    sys.path.remove("../py_src") # Hacky way to add higher directory to python modules path. 
except:
    pass
sys.path.append("../py_src") # Means that I dont have to make src/ a proper python package

# %%
from run import bilby_inference_run

bilby_inference_run(arg_name='test',seed=1234)
# Out:
# INFO:root:Welcome to the Kalman Filter Nested Sampler for estimating pulsar braking indices

# %%
from system_parameters import SystemParameters
from synthetic_data import SyntheticData
from plotting import plot_states_and_observation
seed = 1234

P1   = SystemParameters(seed=seed,σp=1e-25) 
data1 = SyntheticData(P1)                         
plot_states_and_observation(P1.t,data1.state,data1.observation)
# Out:
# INFO:root:Welcome to the Kalman Filter Nested Sampler for estimating pulsar braking indices
